# %%
import hashlib
import re
from datetime import datetime, timezone
import pandas as pd

# %%
EXCLUSION_LIST = ['BLANK', '-', 'NA', 'NONE', '{NULL}']

# %%
# clean column names
def clean_cols(df: pd.DataFrame) -> pd.DataFrame:
    df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
    return df

# %%
def clean_dob(dob, age):
    if dob > datetime.now() and age < 100:
        dob = dob.replace(year=datetime.now().year - age)
    if age >= 100 and dob.year > datetime.now().year - 100:
        dob = dob.replace(year=datetime.now().year - age)
    return dob

# %%
def clean_column(value, exclusions=EXCLUSION_LIST):
    if isinstance(value, str) and value.strip().upper() in exclusions:
        return None
    elif isinstance(value, float) and pd.isna(value):
        return None
    else:
        return value

# %%
def hash_password(pw: str) -> str:
    if pw is None:
        return None
    else:
        return hashlib.sha256(pw.encode('utf-8')).hexdigest()

# %%
def clean_salary(salary: str) -> str:
    if salary is None:
        return None
    else:
        return re.sub(r'[^\d.]', '', salary)

# %%
users_uk = pd.read_csv('data/UK User Data.csv', encoding='latin1')
users_uk = clean_cols(users_uk)
users_uk['dob'] = pd.to_datetime(users_uk['dob'], format='%d/%m/%y', errors='coerce')
users_uk.head()

# %%
from psutil import users


users_fr = pd.read_csv('data/FR User Data.csv', encoding='utf8')
users_fr = clean_cols(users_fr)
users_fr['dob'] = pd.to_datetime(users_fr['ddn'], format='%y/%m/%d', errors='coerce')
users_fr.head()
# Out:
#                 prénom nom_de_famille       ddn  âge_dernier_anniversaire  \
# 0     Adèle Françoise          Bisset  16-10-01                       108
# 1      Adrien Jacques          Abadie  85-05-05                        39
# 2  Bruno Jean-Baptiste      Chevrolet  30-06-26                        94
# 3            Cassandre        Fortier  02-03-01                        22
# 4                Ugène         Gagnon  48-01-05                        77
#
#   couleur_préférée animal_préféré     plat_préféré genre     mot_de_passe  \
# 0            Jaune          Tigre      Ratatouille     F  BUXe$E2Y/4+mX!J
# 1             Bleu         Cheval        Cassoulet     M  t4BPtPe.Nis/EJS
# 2             Gris         Mouton  Quiche lorraine     M  68,cj%L4wALVksu
# 3           Marron          Poule           Crêpes  vide  vXE,E!9dK,cq4_2
# 4            Rouge         Cochon    Bouillabaisse     -  ?de/7C9eJ?SdmsZ
#
#           ville      département  code_postal       adresse_électronique  \
# 0  Villevenard             Marne        51270          bisset16@live.com
# 1         Lille             Nord        59800       ajabadie@outlook.com
# 2        Tarbes  Hautes-Pyrénées        65000        bjbchevy30@live.com
# 3       Béziers          Hérault        34500  fortier02@webmail.free.fr
# 4       Créteil     Val-de-Marne        94000       rougecouchon@mail.ru
#
#         téléphone        portable          bac+   salaire  \
# 0  03 26 80 52 40  06 11 53 00 93  Baccalauréat  1.581,00
# 1  03 20 15 84 40  06 81 43 00 10    Licentiate  2.979,50
# 2  05 62 34 32 36  06 88 76 27 26  Baccalauréat  1.058,00
# 3  04 67 36 73 73  06 77 70 77 03        Master  3.785,50
# 4  01 83 75 56 56  06 01 00 00 69           CFA  1.581,00
#
#    visites_du_site_web_au_cours_des_30_derniers_jours dob
# 0                                                 17  NaT
# 1                                                 25  NaT
# 2                                                 29  NaT
# 3                                                 44  NaT
# 4                                                  7  NaT

# %%
list(users_uk.columns)
# Out:
# ['first_name',
#  'surname',
#  'middle_initials',
#  'dob',
#  'age_last_birthday',
#  'favourite_colour',
#  'favourite_animal',
#  'favourite_food',
#  'gender',
#  'password',
#  'city',
#  'county',
#  'postcode',
#  'email',
#  'phone',
#  'mobile',
#  'rqf',
#  'salary',
#  'website_visits_last_30_days']

# %%
fr_columns = list(users_uk.columns)
fr_columns.remove('middle_initials')
fr_columns[-3] = 'education' 

users_fr.columns = users_uk.columns

# %%
users_fr.head()
# Out:
#             first_name    surname middle_initials  dob age_last_birthday  \
# 0     Adèle Françoise      Bisset        16-10-01  108             Jaune
# 1      Adrien Jacques      Abadie        85-05-05   39              Bleu
# 2  Bruno Jean-Baptiste  Chevrolet        30-06-26   94              Gris
# 3            Cassandre    Fortier        02-03-01   22            Marron
# 4                Ugène     Gagnon        48-01-05   77             Rouge
#
#   favourite_colour favourite_animal favourite_food           gender  \
# 0            Tigre      Ratatouille              F  BUXe$E2Y/4+mX!J
# 1           Cheval        Cassoulet              M  t4BPtPe.Nis/EJS
# 2           Mouton  Quiche lorraine              M  68,cj%L4wALVksu
# 3            Poule           Crêpes           vide  vXE,E!9dK,cq4_2
# 4           Cochon    Bouillabaisse              -  ?de/7C9eJ?SdmsZ
#
#        password             city  county                   postcode  \
# 0  Villevenard             Marne   51270          bisset16@live.com
# 1         Lille             Nord   59800       ajabadie@outlook.com
# 2        Tarbes  Hautes-Pyrénées   65000        bjbchevy30@live.com
# 3       Béziers          Hérault   34500  fortier02@webmail.free.fr
# 4       Créteil     Val-de-Marne   94000       rougecouchon@mail.ru
#
#             email           phone        mobile       rqf  salary  \
# 0  03 26 80 52 40  06 11 53 00 93  Baccalauréat  1.581,00      17
# 1  03 20 15 84 40  06 81 43 00 10    Licentiate  2.979,50      25
# 2  05 62 34 32 36  06 88 76 27 26  Baccalauréat  1.058,00      29
# 3  04 67 36 73 73  06 77 70 77 03        Master  3.785,50      44
# 4  01 83 75 56 56  06 01 00 00 69           CFA  1.581,00       7
#
#   website_visits_last_30_days
# 0                         NaT
# 1                         NaT
# 2                         NaT
# 3                         NaT
# 4                         NaT

# %% [markdown]
# Headers
# Fix doB so it's consistent
# map gender to conform to uk
# check location matches UK format
# telephone number spaces
# BAC+ mapping to RQF
# Salary is in euros, . and , are swapped. monthly instead of annually

# %%
# clean columns
for col in users.columns:
    users[col] = users[col].apply(clean_column)
# hash passwords
users['password'] = users['password'].apply(hash_password)
# clean dob
users['dob'] = users.apply(lambda x: clean_dob(x['dob'], x['age_last_birthday']), axis=1)
# clean salary
users['salary'] = users['salary'].apply(clean_salary)

# %%
# import other file
# 'Website Visits' validation

# %%
def clean_timestamp(ts):
    return datetime.fromtimestamp(ts, tz=timezone.utc).strftime('%Y-%m-%d %H:%M:%S')

# %%
logins = pd.read_csv('data/UK-User-LoginTS.csv')
logins = clean_cols(logins)
logins['logints'] = logins['logints'].apply(clean_timestamp)
logins.columns = ['login_id', 'username', 'login_timestamp']
logins.head()
# Out:
#    login_id           username      login_timestamp
# 0         1  card49a@gmail.com  2025-01-05 10:12:40
# 1         2  card49a@gmail.com  2025-01-09 20:39:23
# 2         3  card49a@gmail.com  2025-01-14 06:52:53
# 3         4  card49a@gmail.com  2025-01-18 17:10:01
# 4         5  card49a@gmail.com  2025-01-23 03:28:32

# %%
# quick validation
# logins.isna().sum()
# logins.info()

# %%
import sqlite3

print(sqlite3.sqlite_version)
# Out:
# 3.50.4

# %%
import sqlite3

conn = sqlite3.connect("customers.db")

with open("create_database.sql", "r", encoding="utf-8") as f:
    sql_script = f.read()

conn.executescript(sql_script)
conn.commit()
conn.close()

# %%
conn = sqlite3.connect("customers.db")
users.to_sql('users', conn, if_exists='append', index=False)
logins.to_sql('logins', conn, if_exists='append', index=False)

conn.close()
